# %%
# STEP 1: Import Required Libraries
import nltk
from nltk.tokenize import word_tokenize as wt
from nltk import pos_tag as tagger
import re

nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
# Sample dataset (different text for originality)
paragraph = """Artificial intelligence is transforming industries and improving decision making.
It enables systems to learn from data and perform tasks efficiently.
Applications include speech recognition, recommendation systems, and automation."""

# -------------------------------
# Step 1: Text Cleaning
# -------------------------------
clean_text = paragraph.lower()
clean_text = re.sub(r'[^a-z\s]', '', clean_text)

# -------------------------------
# Step 2: Tokenization
# -------------------------------
words = wt(clean_text)

# -------------------------------
# Step 3: POS Tagging
# -------------------------------
tagged_output = tagger(words)

# -------------------------------
# Display Output
# -------------------------------
print("\nPOS Tagging Result:\n")

for w, t in tagged_output:
    print(f"{w} : {t}")
# Out:
# POS Tagging Result:
#
# artificial : JJ
# intelligence : NN
# is : VBZ
# transforming : VBG
# industries : NNS
# and : CC
# improving : VBG
# decision : NN
# making : VBG
# it : PRP
# enables : VBZ
# systems : NNS
# to : TO
# learn : VB
# from : IN
# data : NNS
# and : CC
# perform : VB
# tasks : NNS
# efficiently : RB
# applications : NNS
# include : VBP
# speech : JJ
# recognition : NN
# recommendation : NN
# systems : NNS
# and : CC
# automation : NN
